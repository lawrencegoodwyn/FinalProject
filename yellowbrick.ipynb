# %%
import pandas as pd
import yellowbrick as yb
import matplotlib.pyplot as plt
import csv
import os
from yellowbrick.features.rankd import Rank2D
from yellowbrick.features.radviz import RadViz
from yellowbrick.features.pcoords import ParallelCoordinates
from sklearn.ensemble import RandomForestClassifier
from yellowbrick.model_selection import FeatureImportances
import pandas as pd

# %%
gainesville_total = os.path.join("Dashboard","TransformGainesville_CrimesALL.csv")
data = pd.read_csv(gainsville_total)
data.head()
# Out:
#    Unnamed: 0         ID                          CFS CFS_Type Classification  \
# 0           0  221009267  Domestic Aggravated Battery  Battery         Person
# 1           1  221009608  Domestic Aggravated Battery  Battery         Person
# 2           2  221009391  Domestic Aggravated Battery  Battery         Person
# 3           3  221009308  Domestic Aggravated Battery  Battery         Person
# 4           4  221011388  Domestic Aggravated Battery  Battery         Person
#
#   offenseDate  offenseHour offenseDOW       reportDate  reportHour  ...  \
# 0    7/4/2021           21     Sunday   7/4/2021 22:37          22  ...
# 1   7/11/2021           22     Sunday  7/11/2021 22:55          22  ...
# 2    7/7/2021           19  Wednesday   7/7/2021 19:13          19  ...
# 3    7/6/2021            7    Tuesday    7/6/2021 7:27           7  ...
# 4   8/16/2021           17     Monday  8/16/2021 17:26          17  ...
#
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'ID', 'CFS', 'CFS_Type', 'Classification', 'offenseDate',
#        'offenseHour', 'offenseDOW', 'reportDate', 'reportHour', 'reportDOW',
#        'city', 'state', 'address', 'latitude', 'longitude', 'location',
#        'date ', 'month', 'day', 'year', 'fullDate', 'DOW', 'time ',
#        'moonPhase'],
#       dtype='object')

# %%
unused_columns= ['Unnamed: 0', 'ID', 'CFS', 'CFS_Type', 'Classification', 'offenseDate',
       'offenseHour', 'offenseDOW', 'reportDate', 'reportHour', 'reportDOW',
       'city', 'state', 'address', 'latitude', 'longitude', 'location',
       'date ', 'month', 'day', 'year', 'fullDate', 'DOW', 'time ',
       'moonPhase']

# %%
df=data.drop[unused_columns,axis=1]

# %%
#Covnert Strings to FLoats

# Use get_dummies() to create variables for text features.
X = pd.get_dummies(crypto_df, columns=["Algorithm", "ProofType"])
print(X.shape)


gville = pd.get_dummies(columns= [])

# %%
# Specify the features of interest
features = [
        'CFS','CFS_Type','Classification','offenseDate' ,'offenseDOW','reportDate','reportHour', 'reportDOW','latitude','longitude','fullDate','DOW','moonPhase'
    ]

# %%
# Extract the numpy arrays from the data frame
X = data[features].values
y = data.values

# %%
# Load the classification data set
#X, y =

# %%
viz = FeatureImportances(model)
viz.fit(X, y)
viz.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16176/3599497895.py in <module>
#       1 viz = FeatureImportances(model)
# ----> 2 viz.fit(X, y)
#       3 viz.show()
#
# ~\anaconda3\envs\yellowbrick\lib\site-packages\yellowbrick\model_selection\importances.py in fit(self, X, y, **kwargs)
#     174         """
#     175         # Super call fits the underlying estimator if it's not already fitted
# --> 176         super(FeatureImportances, self).fit(X, y, **kwargs)
#     177
#     178         # Get the feature importances from the model
#
# ~\anaconda3\envs\yellowbrick\lib\site-packages\yellowbrick\base.py in fit(self, X, y, **kwargs)
#     388         """
#     389         if not check_fitted(self.estimator, is_fitted_by=self.is_fitted):
# --> 390             self.estimator.fit(X, y, **kwargs)
#     391         return self
#     392
#
# ...
