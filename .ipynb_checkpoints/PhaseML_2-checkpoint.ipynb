# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np
import pandas as pd
from pathlib import Path
from collections import Counter

# %%
from sklearn.metrics import balanced_accuracy_score
from sklearn.metrics import confusion_matrix
from imblearn.metrics import classification_report_imbalanced

# %%
# Load the data
df = pd.read_csv('TransformGainesville_CrimesALL.csv', index_col = 0)

df.head()
# Out:
#           ID                          CFS CFS_Type Classification  \
# 0  221009267  Domestic Aggravated Battery  Battery         Person
# 1  221009608  Domestic Aggravated Battery  Battery         Person
# 2  221009391  Domestic Aggravated Battery  Battery         Person
# 3  221009308  Domestic Aggravated Battery  Battery         Person
# 4  221011388  Domestic Aggravated Battery  Battery         Person
#
#            offenseDate  offenseHour offenseDOW       reportDate  reportHour  \
# 0  2021-07-04 21:24:00           21     Sunday   7/4/2021 22:37          22
# 1  2021-07-11 22:54:00           22     Sunday  7/11/2021 22:55          22
# 2  2021-07-07 19:12:00           19  Wednesday   7/7/2021 19:13          19
# 3  2021-07-06 07:26:00            7    Tuesday    7/6/2021 7:27           7
# 4  2021-08-16 17:25:00           17     Monday  8/16/2021 17:26          17
#
#    reportDOW  ...  longitude                               location date   \
# 0     Sunday  ... -82.326069  POINT (-82.326069 29.688534000000004)   NaN
# 1     Sunday  ... -82.387148  POINT (-82.387148 29.632687000000004)   NaN
# 2  Wednesday  ... -82.299390            POINT (-82.29939 29.640249)   NaN
# 3    Tuesday  ... -82.398242           POINT (-82.398242 29.641625)   NaN
# 4     Monday  ... -82.326069  POINT (-82.326069 29.688534000000004)   NaN
#
#    month  day year fullDate  DOW  time   moonPhase
# 0    NaN  NaN  NaN      NaN  NaN    NaN        NaN
# 1    NaN  NaN  NaN      NaN  NaN    NaN        NaN
# 2    NaN  NaN  NaN      NaN  NaN    NaN        NaN
# 3    NaN  NaN  NaN      NaN  NaN    NaN        NaN
# 4    NaN  NaN  NaN      NaN  NaN    NaN        NaN
#
# [5 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['ID', 'CFS', 'CFS_Type', 'Classification', 'offenseDate', 'offenseHour',
#        'offenseDOW', 'reportDate', 'reportHour', 'reportDOW', 'city', 'state',
#        'address', 'latitude', 'longitude', 'location', 'date ', 'month', 'day',
#        'year', 'fullDate', 'DOW', 'time ', 'moonPhase'],
#       dtype='object')

# %%
#Find out unique names of CFS, CFS_type, and moonPhase

# %%
df.Classification.unique()
# Out:
# array(['Person', 'Other ', 'Property', 'Government'], dtype=object)

# %%
df.CFS.unique()
# Out:
# array(['Domestic Aggravated Battery', 'Domestic Simple Battery',
#        'Trespass Warning', 'Dating Violence Simple Battery',
#        'Domestic Disturbance', 'Burglary to Residence', 'Fire',
#        'Theft Grand - Retail', 'Driving Under the Influence',
#        'Death Investigation', 'Robbery (armed)', 'Theft Petit - Other',
#        'Weapons Violation (possessing/concealing)',
#        'Drug Poss. of Controlled Substance', 'Damage to Property',
#        'Robbery (strong Arm)', 'Theft Petit - Retail',
#        'Suspicious Incident', 'Domestic Violence Injunction Violation',
#        'Stolen Vehicle (auto)', 'Trespass', 'Burglary to Conveyance',
#        'Loitering and Prowling', 'Stolen Vehicle (motorcycle)',
#        'Identity Theft', 'Disturbance',
#        'Fraud (obtain Money/property by False Pretense)',
#        'Battery (simple)', 'Violation of Temporary Injunction',
#        'Criminal Mischief (misdemeanor)', 'Robbery',
#        'Domestic Battery by Strangulation', 'Making False 911 Call',
#        'Fraud (credit Card/atm)', 'Found Property', 'Disorderly Conduct',
#        'Traffic Offense (all Other)', 'Battery (aggravated)',
#        'Burglary to Business', 'Stolen Vehicle (other)',
#        'Disturbance Civil', 'Fraud (forgery)', 'Sick / Injured Person',
#        'Theft Petit - From Building', 'Battery (felony)', 'Arson',
#        'Theft Grand - Other', 'Harassing/ Obscene Calls',
#        'Theft Petit - Bicycle', 'Affray',
#        'Assault (police Officer Aggravated)', 'Drug Equip/paraphernalia',
#        'Criminal Mischief (felony)', 'Drug Violation (using)',
#        'Computer Crimes', 'Domestic Aggravated Assualt',
#        'Juvenile Problem / Disturbance', 'Fraud (all Other)',
#        'Drug Violation', 'Assault (aggravated)',
#        'Battery (police Officer)', 'Robbery by Sudden Snatching',
#        'Battery (security Guard/officer)', 'Drug Violation (selling)',
#        'Exposure of Sexual Organs / Indecent Exposure',
#        'Driving While License Suspended/revoked', 'Fraud (impersonation)',
#        'Animal Attack', 'Missing Person', 'Robbery (carjacking)',
#        'Damage to City Property', 'Drug Violation (sid)',
#        'Violation of Pretrial Release', 'Homicide',
#        'Resist/obstructing Without Violence',
#        'Flee/attempt to Elude Police Officer',
#        'Discharge Firearm in Public',
#        'Stolen Property (buying/receiving)',
#        'Theft Grand - From Building', 'Domestic Assault', 'Harassment',
#        'Runaway', 'Animal Cruelty', 'Robbery (home Invasion)',
#        'Escaped Prisoner', 'Counterfeiting',
#        'Battery on a Person 65 Yoa or Older',
#        'Theft Petit - Purse Snatching', 'Tampering With Evidence',
#        'Theft Grand - From Vehicle (vehicle Parts)',
#        'Domestic Felony Battery Repeat Offender',
#        'Dating Violence Aggravated Battery',
#        'Resisting Merchant Detainment',
#        'Theft Petit - From Vehicle/not Parts',
#        'Theft Grand - Pocket-picking', 'Assault (simple)',
#        'Cyber Stalking', 'Dating Violence Felony Battery',
#        'Resist/obstructing With Violence', 'Animal Problem',
#        'Indecent Exposure', 'Weapons Violation', 'Stalking (simple)',
#        'Battery on a Emergency Medicalcare Provider',
#        'Uttering Forged Instruments',
#        'Theft Petit - From Vending Machine', 'Fraud (worthless Check)',
#        'Stalking (aggravated)', 'Violation of Probation',
#        'Exploitation of the Elderly/disabled',
#        'Theft Petit - From Vehicle (vehicle Parts)',
#        'Utter Forged/counterfeit Bill',
#        'Battery on a School Board Employee',
#        'Sex Offender/predator Violation <48 Hrs',
#        'Possession of Child Pornography', 'Verbal Threats',
#        'Theft Grand - From Vehicle (not Parts)',
#        'Dating Violence Aggravated Stalking',
#        'Written Threat to Kill or Injure', 'Theft Grand - Bicycle',
#        'Burglary to a Structure',
#        'Stolen Property (selling/distributing)', 'Stolen Vehicle (truck)',
#        'Bomb Threat', 'Disorderly Intoxication',
#        'Violation of Permanent Injunction',
#        'Dating Violence Injunction Violation', 'Extortion/threats',
#        'Theft Petit - Trailer', 'Trash Dumping', 'Theft Grand - Trailer',
#        'Crimes Against the Elderly', 'Theft Petit - Pocket-picking',
#        'Poss. of Alcohol Under 21 Yoa',
#        'Dating Violence Aggravated Assault', 'False Info to Leo',
#        'Filing False Police Report', 'False Imprisonment(kidnap)',
#        'Threatening Phone Calls', 'Baker Act', 'Stolen Vehicle (scooter)',
#        'Luring or Enticing a Child', 'Sexual Battery', 'Child Neglect',
#        'Marchman Act', 'Armed Burglary of a Dwelling or Structure',
#        'Threats', 'Dating Violence False Imprisonment',
#        'Theft Grand -firearm',
#        'Lewd or Lascivious Exhibition Offender 18', 'Overdose', 'Suicide',
#        'Fraud (embezzlement)', 'Disruption of School Function',
#        'Violation of Probation - Juvenile',
#        'Stolen Property (possession/conceal)', 'Driving With No License',
#        'Vehicle Not Registered', 'Hit & Run', 'Reckless Driving',
#        'Noise Complaint', 'City Ordinance Violation',
#        'Drug Violation (buying)', 'Tamper W/victim Witness',
#        'Molestation of Vending Machine', 'Aircraft Incident',
#        'Violation of Home Detention - Juvenile',
#        'Stalking - Vio. of Court Order',
#        'Dating Violence Simple Stalking',
#        'Theft Grand - From Vending Machine',
#        'Presenting Dl of Another as Own', 'Money Laundering',
#        'Unauthorized Poss Manuf Fl Dl',
#        'Possession of Less Than 20g of Cannabis',
#        'Battery (police Officer Aggravated)',
#        'False Info on Pawn Transaction Form', 'Gambling',
#        'Open House Party', 'False Alarms of Fires First Offense',
#        'Prostitution', 'Career Offender Violation', 'Panhandling',
#        'Fraud (welfare)', 'All Other Liquor Law Viol.',
#        'Battery (security Guard/officer Aggravated)', 'Criminal Mischief',
#        'Theft Grand - Purse Snatching', 'Falsely Personating Officer',
#        'Gas Drive Off'], dtype=object)

# %%
df.CFS_Type.unique()
# Out:
# array(['Battery', 'Quality of Life', 'Theft', 'Other', 'Alcohol',
#        'Death Inv/Homicide', 'Gov Reg Vio', 'Drugs', 'Fraud', 'Assault',
#        'Suicide'], dtype=object)

# %%
df.moonPhase.unique()
# Out:
# array([nan, 'Full Moon ', 'First Quarter', 'New  Moon ', 'Third Quarter'],
#       dtype=object)

# %%
# I think previous cell took out all NaNs, which skews data because now there's no data in which there's not a moon phase attached to it?

# %%
# Dropping CFS column because there's too many data points

# %%
unused_cols = ['CFS','reportDate', 'offenseHour','reportHour','reportDOW','city','state','address','longitude','latitude','day','location','date ','month','year']

df = df.drop(unused_cols, axis = 1)

df.head(50)
# Out:
#            ID CFS_Type Classification          offenseDate offenseDOW  \
# 0   221009267  Battery         Person  2021-07-04 21:24:00     Sunday
# 1   221009608  Battery         Person  2021-07-11 22:54:00     Sunday
# 2   221009391  Battery         Person  2021-07-07 19:12:00  Wednesday
# 3   221009308  Battery         Person  2021-07-06 07:26:00    Tuesday
# 4   221011388  Battery         Person  2021-08-16 17:25:00     Monday
# 5   221011524  Battery         Person  2021-08-19 07:30:00   Thursday
# 6   221012057  Battery         Person  2021-08-28 16:24:00   Saturday
# 7   221012231  Battery         Person  2021-08-31 23:53:00    Tuesday
# 8   221012341  Battery         Person  2021-09-02 19:04:00   Thursday
# 9   221013249  Battery         Person  2021-09-19 19:35:00     Sunday
# 10  221014033  Battery         Person  2021-10-02 16:24:00   Saturday
# 11  221014308  Battery         Person  2021-10-07 16:00:00   Thursday
# 12  221014905  Battery         Person  2021-10-18 14:25:00     Monday
# 13  221015541  Battery         Person  2021-10-30 01:10:00   Saturday
# 14  221015627  Battery         Person  2021-11-01 02:00:00     Monday
# 15  221015394  Battery         Person  2021-10-27 15:40:00  Wednesday
# 16  221016364  Battery         Person  2021-11-14 12:00:00     Sunday
# 17  221016505  Battery         Person  2021-11-17 15:58:00  Wednesday
# 18  221017434  Battery         Person  2021-12-04 18:00:00   Saturday
# 19  221017379  Battery         Person  2021-12-03 22:15:00     Friday
# 20  221017317  Battery         Person  2021-12-02 18:40:00   Thursday
# 21  221018378  Battery         Person  2021-12-22 23:00:00  Wednesday
# 22  219009416  Battery         Person  2019-06-08 00:20:00   Saturday
# 23  220018564  Battery         Person  2020-12-29 07:00:00    Tuesday
# 24  219021546  Battery         Person  2019-12-30 09:45:00     Monday
# 25  220006659  Battery         Person  2020-05-18 07:04:00     Monday
# 26  220003226  Battery         Person  2020-02-26 21:51:00  Wednesday
# 27  221005161  Battery         Person  2021-04-14 03:00:00  Wednesday
# 28  221005746  Battery         Person  2021-04-26 05:30:00     Monday
# 29  220005261  Battery         Person  2020-04-12 00:01:00     Sunday
# 30  221001962  Battery         Person  2021-02-11 01:40:00   Thursday
# 31  220018102  Battery         Person  2020-07-05 19:55:00     Sunday
# 32  220010783  Battery         Person  2020-08-05 15:45:00  Wednesday
# 33  220004295  Battery         Person  2020-03-16 15:30:00     Monday
# 34  220011788  Battery         Person  2020-08-24 11:17:00     Monday
# 35  220011288  Battery         Person  2020-08-14 19:10:00     Friday
# 36  221000718  Battery         Person  2021-01-15 03:13:00     Friday
# 37  220014433  Battery         Person  2020-10-11 13:35:00     Sunday
# 38  219010229  Battery         Person  2019-06-21 18:20:00     Friday
# 39  220018304  Battery         Person  2020-12-22 19:00:00    Tuesday
# 40  220008878  Battery         Person  2020-06-29 21:00:00     Monday
# 41  221001778  Battery         Person  2021-02-07 19:20:00     Sunday
# 42  220012564  Battery         Person  2020-09-07 17:08:00     Monday
# 43  220017231  Battery         Person  2020-12-02 02:50:00  Wednesday
# 44  220009837  Battery         Person  2020-07-18 01:11:00   Saturday
# 45  220000879  Battery         Person  2020-01-16 07:29:00   Thursday
# 46  220003604  Battery         Person  2020-03-04 12:52:00  Wednesday
# 47  220004536  Battery         Person  2020-03-22 04:50:00     Sunday
# 48  220004373  Battery         Person  2020-03-17 18:17:00    Tuesday
# 49  221006878  Battery         Person  2021-05-18 00:35:00    Tuesday
#
#    fullDate  DOW time  moonPhase
# 0       NaN  NaN   NaN       NaN
# 1       NaN  NaN   NaN       NaN
# 2       NaN  NaN   NaN       NaN
# 3       NaN  NaN   NaN       NaN
# 4       NaN  NaN   NaN       NaN
# 5       NaN  NaN   NaN       NaN
# 6       NaN  NaN   NaN       NaN
# 7       NaN  NaN   NaN       NaN
# 8       NaN  NaN   NaN       NaN
# 9       NaN  NaN   NaN       NaN
# 10      NaN  NaN   NaN       NaN
# 11      NaN  NaN   NaN       NaN
# 12      NaN  NaN   NaN       NaN
# 13      NaN  NaN   NaN       NaN
# 14      NaN  NaN   NaN       NaN
# 15      NaN  NaN   NaN       NaN
# 16      NaN  NaN   NaN       NaN
# 17      NaN  NaN   NaN       NaN
# 18      NaN  NaN   NaN       NaN
# 19      NaN  NaN   NaN       NaN
# 20      NaN  NaN   NaN       NaN
# 21      NaN  NaN   NaN       NaN
# 22      NaN  NaN   NaN       NaN
# 23      NaN  NaN   NaN       NaN
# 24      NaN  NaN   NaN       NaN
# 25      NaN  NaN   NaN       NaN
# 26      NaN  NaN   NaN       NaN
# 27      NaN  NaN   NaN       NaN
# 28      NaN  NaN   NaN       NaN
# 29      NaN  NaN   NaN       NaN
# 30      NaN  NaN   NaN       NaN
# 31      NaN  NaN   NaN       NaN
# 32      NaN  NaN   NaN       NaN
# 33      NaN  NaN   NaN       NaN
# 34      NaN  NaN   NaN       NaN
# 35      NaN  NaN   NaN       NaN
# 36      NaN  NaN   NaN       NaN
# 37      NaN  NaN   NaN       NaN
# 38      NaN  NaN   NaN       NaN
# 39      NaN  NaN   NaN       NaN
# 40      NaN  NaN   NaN       NaN
# 41      NaN  NaN   NaN       NaN
# 42      NaN  NaN   NaN       NaN
# 43      NaN  NaN   NaN       NaN
# 44      NaN  NaN   NaN       NaN
# 45      NaN  NaN   NaN       NaN
# 46      NaN  NaN   NaN       NaN
# 47      NaN  NaN   NaN       NaN
# 48      NaN  NaN   NaN       NaN
# 49      NaN  NaN   NaN       NaN

# %%
# Convert CFS_Type and moonPhase with get dummies

convert_cols = df[["CFS_Type", "moonPhase"]]
convert_cols
# Out:
#           CFS_Type moonPhase
# 0          Battery       NaN
# 1          Battery       NaN
# 2          Battery       NaN
# 3          Battery       NaN
# 4          Battery       NaN
# ...            ...       ...
# 44868      Battery       NaN
# 44869        Other       NaN
# 44870        Theft       NaN
# 44871  Gov Reg Vio       NaN
# 44872        Theft       NaN
#
# [44873 rows x 2 columns]

# %%
# Merge dummy columns into main dataframe and drop originals 

new_columns_df = pd.get_dummies(convert_cols)
new_columns_df
# Out:
#        CFS_Type_Alcohol  CFS_Type_Assault  CFS_Type_Battery  \
# 0                     0                 0                 1
# 1                     0                 0                 1
# 2                     0                 0                 1
# 3                     0                 0                 1
# 4                     0                 0                 1
# ...                 ...               ...               ...
# 44868                 0                 0                 1
# 44869                 0                 0                 0
# 44870                 0                 0                 0
# 44871                 0                 0                 0
# 44872                 0                 0                 0
#
#        CFS_Type_Death Inv/Homicide  CFS_Type_Drugs  CFS_Type_Fraud  \
# 0                                0               0               0
# 1                                0               0               0
# 2                                0               0               0
# 3                                0               0               0
# 4                                0               0               0
# ...                            ...             ...             ...
# 44868                            0               0               0
# 44869                            0               0               0
# 44870                            0               0               0
# 44871                            0               0               0
# 44872                            0               0               0
#
#        CFS_Type_Gov Reg Vio  CFS_Type_Other  CFS_Type_Quality of Life  \
# 0                         0               0                         0
# 1                         0               0                         0
# 2                         0               0                         0
# 3                         0               0                         0
# 4                         0               0                         0
# ...                     ...             ...                       ...
# 44868                     0               0                         0
# 44869                     0               1                         0
# 44870                     0               0                         0
# 44871                     1               0                         0
# 44872                     0               0                         0
#
#        CFS_Type_Suicide  CFS_Type_Theft  moonPhase_First Quarter  \
# 0                     0               0                        0
# 1                     0               0                        0
# 2                     0               0                        0
# 3                     0               0                        0
# 4                     0               0                        0
# ...                 ...             ...                      ...
# 44868                 0               0                        0
# 44869                 0               0                        0
# 44870                 0               1                        0
# 44871                 0               0                        0
# 44872                 0               1                        0
#
#        moonPhase_Full Moon   moonPhase_New  Moon   moonPhase_Third Quarter
# 0                         0                     0                        0
# 1                         0                     0                        0
# 2                         0                     0                        0
# 3                         0                     0                        0
# 4                         0                     0                        0
# ...                     ...                   ...                      ...
# 44868                     0                     0                        0
# 44869                     0                     0                        0
# 44870                     0                     0                        0
# 44871                     0                     0                        0
# 44872                     0                     0                        0
#
# [44873 rows x 15 columns]

# %%
# Drop old columns and merge or CONCATENATE on index

df = df.drop(['CFS_Type',"moonPhase"], axis = 1)

# %%
new_df = pd.merge(df,new_columns_df, left_index=True, right_index = True )
new_df
# Out:
#               ID Classification          offenseDate offenseDOW fullDate  DOW  \
# 0      221009267         Person  2021-07-04 21:24:00     Sunday      NaN  NaN
# 1      221009608         Person  2021-07-11 22:54:00     Sunday      NaN  NaN
# 2      221009391         Person  2021-07-07 19:12:00  Wednesday      NaN  NaN
# 3      221009308         Person  2021-07-06 07:26:00    Tuesday      NaN  NaN
# 4      221011388         Person  2021-08-16 17:25:00     Monday      NaN  NaN
# ...          ...            ...                  ...        ...      ...  ...
# 44868  219004357         Person  2019-03-14 22:45:00   Thursday      NaN  NaN
# 44869  218014815       Property  2018-08-15 12:15:00  Wednesday      NaN  NaN
# 44870  218019557       Property  2018-10-23 14:53:00    Tuesday      NaN  NaN
# 44871  218017216     Government  2018-09-18 21:46:00    Tuesday      NaN  NaN
# 44872  218011979       Property  2018-07-01 19:18:00     Sunday      NaN  NaN
#
#       time   CFS_Type_Alcohol  CFS_Type_Assault  CFS_Type_Battery  ...  \
# 0       NaN                 0                 0                 1  ...
# 1       NaN                 0                 0                 1  ...
# 2       NaN                 0                 0                 1  ...
# 3       NaN                 0                 0                 1  ...
# 4       NaN                 0                 0                 1  ...
# ...     ...               ...               ...               ...  ...
# 44868   NaN                 0                 0                 1  ...
# 44869   NaN                 0                 0                 0  ...
# 44870   NaN                 0                 0                 0  ...
# 44871   NaN                 0                 0                 0  ...
# 44872   NaN                 0                 0                 0  ...
#
#        CFS_Type_Fraud  CFS_Type_Gov Reg Vio  CFS_Type_Other  \
# 0                   0                     0               0
# 1                   0                     0               0
# 2                   0                     0               0
# 3                   0                     0               0
# 4                   0                     0               0
# ...               ...                   ...             ...
# 44868               0                     0               0
# 44869               0                     0               1
# 44870               0                     0               0
# 44871               0                     1               0
# 44872               0                     0               0
#
#        CFS_Type_Quality of Life  CFS_Type_Suicide  CFS_Type_Theft  \
# 0                             0                 0               0
# 1                             0                 0               0
# 2                             0                 0               0
# 3                             0                 0               0
# 4                             0                 0               0
# ...                         ...               ...             ...
# 44868                         0                 0               0
# 44869                         0                 0               0
# 44870                         0                 0               1
# 44871                         0                 0               0
# 44872                         0                 0               1
#
#        moonPhase_First Quarter  moonPhase_Full Moon   moonPhase_New  Moon   \
# 0                            0                     0                     0
# 1                            0                     0                     0
# 2                            0                     0                     0
# 3                            0                     0                     0
# 4                            0                     0                     0
# ...                        ...                   ...                   ...
# 44868                        0                     0                     0
# 44869                        0                     0                     0
# 44870                        0                     0                     0
# 44871                        0                     0                     0
# 44872                        0                     0                     0
#
#        moonPhase_Third Quarter
# 0                            0
# 1                            0
# 2                            0
# 3                            0
# 4                            0
# ...                        ...
# 44868                        0
# 44869                        0
# 44870                        0
# 44871                        0
# 44872                        0
#
# [44873 rows x 22 columns]

# %%
y = pd.get_dummies(new_df['Classification'])


X = new_df[['CFS_Type_Battery', 'CFS_Type_Quality of Life', 'CFS_Type_Theft', 'CFS_Type_Other', 'CFS_Type_Alcohol',
       'CFS_Type_Death Inv/Homicide', 'CFS_Type_Gov Reg Vio', 'CFS_Type_Drugs', 'CFS_Type_Fraud', 'CFS_Type_Assault',
       'CFS_Type_Suicide','moonPhase_Full Moon ', 'moonPhase_First Quarter', 'moonPhase_New  Moon ', 'moonPhase_Third Quarter']]

# %%
y.value_counts()
# Out:
# Government  Other   Person  Property
# 0           0       0       1           25223
#                     1       0           11705
#             1       0       0            4520
# 1           0       0       0            3425
# dtype: int64

# %%
X.describe()
# Out:
#        CFS_Type_Battery  CFS_Type_Quality of Life  CFS_Type_Theft  \
# count      44873.000000              44873.000000    44873.000000
# mean           0.123237                  0.209948        0.390770
# std            0.328712                  0.407276        0.487928
# min            0.000000                  0.000000        0.000000
# 25%            0.000000                  0.000000        0.000000
# 50%            0.000000                  0.000000        0.000000
# 75%            0.000000                  0.000000        1.000000
# max            1.000000                  1.000000        1.000000
#
#        CFS_Type_Other  CFS_Type_Alcohol  CFS_Type_Death Inv/Homicide  \
# count    44873.000000      44873.000000                 44873.000000
# mean         0.108551          0.007867                     0.013438
# std          0.311078          0.088346                     0.115142
# min          0.000000          0.000000                     0.000000
# 25%          0.000000          0.000000                     0.000000
# 50%          0.000000          0.000000                     0.000000
# 75%          0.000000          0.000000                     0.000000
# max          1.000000          1.000000                     1.000000
#
#        CFS_Type_Gov Reg Vio  CFS_Type_Drugs  CFS_Type_Fraud  CFS_Type_Assault  \
# count          44873.000000    44873.000000    44873.000000      44873.000000
# mean               0.026319        0.041785        0.057585          0.020480
# std                0.160083        0.200099        0.232959          0.141637
# min                0.000000        0.000000        0.000000          0.000000
# 25%                0.000000        0.000000        0.000000          0.000000
# 50%                0.000000        0.000000        0.000000          0.000000
# 75%                0.000000        0.000000        0.000000          0.000000
# max                1.000000        1.000000        1.000000          1.000000
#
#        CFS_Type_Suicide  moonPhase_Full Moon   moonPhase_First Quarter  \
# count      44873.000000          44873.000000             44873.000000
# mean           0.000022              0.004301                 0.003454
# std            0.004721              0.065442                 0.058671
# min            0.000000              0.000000                 0.000000
# 25%            0.000000              0.000000                 0.000000
# 50%            0.000000              0.000000                 0.000000
# 75%            0.000000              0.000000                 0.000000
# max            1.000000              1.000000                 1.000000
#
#        moonPhase_New  Moon   moonPhase_Third Quarter
# count          44873.000000             44873.000000
# mean               0.003922                 0.004368
# std                0.062505                 0.065946
# min                0.000000                 0.000000
# 25%                0.000000                 0.000000
# 50%                0.000000                 0.000000
# 75%                0.000000                 0.000000
# max                1.000000                 1.000000

# %%
X.shape
# Out:
# (44873, 15)

# %%
y.shape
# Out:
# (44873, 4)

# %%
# You can modify test_size to account for 30% testing/70% training
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .3)

# %%
# Resample the training data with the RandomForestClassifier
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=100)

# %%
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
# https://scikit-learn.org/stable/modules/multiclass.html

# %%
from sklearn import metrics

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7524884861090477

# %%
#Confusion Matrix

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test.values.argmax(axis=1), y_pred.argmax(axis=1))
print(cm)
# Out:
# [[ 853    3    0    0]
#  [ 370  760    0    0]
#  [ 802  343 1780    2]
#  [1155  122    0 5029]]

# %%
# Print the  classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       989
#            1       0.62      0.67      0.65      1316
#            2       1.00      0.61      0.76      3497
#            3       1.00      0.80      0.89      7660
#
#    micro avg       0.95      0.75      0.84     13462
#    macro avg       0.90      0.77      0.82     13462
# weighted avg       0.96      0.75      0.84     13462
#  samples avg       0.75      0.75      0.75     13462

# %%
# MODULE DIRECTIONS FOR CONFUSION MATRIX

# Display the confusion matrix
#cm = confusion_matrix(y_test, y_pred)
#cm_df = pd.DataFrame(
    #cm, index=["Actual high_risk", "Actual low_risk"], columns=["Predicted high_risk", "Predicted low_risk"])
#cm_df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/20/_1fhbgyj0hq969tcxqz5trxr0000gn/T/ipykernel_36230/367685298.py in <module>
#       1 # Display the confusion matrix
# ----> 2 cm = confusion_matrix(y_test, y_pred)
#       3 cm_df = pd.DataFrame(
#       4     cm, index=["Actual high_risk", "Actual low_risk"], columns=["Predicted high_risk", "Predicted low_risk"])
#       5 cm_df
#
# ~/opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/sklearn/metrics/_classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight, normalize)
#     302     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     303     if y_type not in ("binary", "multiclass"):
# --> 304         raise ValueError("%s is not supported" % y_type)
#     305
#     306     if labels is None:
#
# ValueError: multilabel-indicator is not supported
