# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

# Import our input dataset
crimes_df = pd.read_csv('TransformGainesville_CrimesALL.csv')
crimes_df
# Out:
#        Unnamed: 0         ID                                          CFS  \
# 0               0  221009267                  Domestic Aggravated Battery
# 1               1  221009608                  Domestic Aggravated Battery
# 2               2  221009391                  Domestic Aggravated Battery
# 3               3  221009308                  Domestic Aggravated Battery
# 4               4  221011388                  Domestic Aggravated Battery
# ...           ...        ...                                          ...
# 44868       44868  219004357  Battery (security Guard/officer Aggravated)
# 44869       44869  218014815                            Criminal Mischief
# 44870       44870  218019557                Theft Grand - Purse Snatching
# 44871       44871  218017216                  Falsely Personating Officer
# 44872       44872  218011979                                Gas Drive Off
#
#           CFS_Type Classification          offenseDate  offenseHour  \
# ...

# %%
# Classify offense type into NON-VIOLENT/Violent

# %%
# Drop NaN ?

# %%
# Identify most common attributes

# %%
crimes_df = crimes_df.dtypes[crimes_df.dtypes == "object"].index.tolist()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /var/folders/20/_1fhbgyj0hq969tcxqz5trxr0000gn/T/ipykernel_14533/2202891461.py in <module>
# ----> 1 crimes_df = crimes_df.dtypes[crimes_df.dtypes == "object"].index.tolist()
#
# AttributeError: 'list' object has no attribute 'dtypes'
